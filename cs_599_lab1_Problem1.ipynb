# %% [markdown]
# <a href="https://colab.research.google.com/github/cnorteye/cs599_deep/blob/main/cs_599_lab1_Problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import random

# Set random seed based on name
def name_to_seed_sum(name):
    return sum(ord(char) for char in name)

first_name = "Comfort"
seed_value = name_to_seed_sum(first_name)

tf.random.set_seed(seed_value)
np.random.seed(seed_value)
random.seed(seed_value)

# Define possible noise types
NOISE_TYPES = ["gaussian", "uniform", "salt_pepper", "laplace"]


# Function to add different types of noise
def add_noise(data, noise_level, noise_type):
    if noise_type == "gaussian":
        return data + tf.random.normal(shape=tf.shape(data), mean=0.0, stddev=noise_level)
    elif noise_type == "uniform":
        return data + tf.random.uniform(shape=tf.shape(data), minval=-noise_level, maxval=noise_level)
    elif noise_type == "laplace":
        return data + tf.convert_to_tensor(np.random.laplace(loc=0.0, scale=noise_level, size=data.shape), dtype=tf.float32)
    elif noise_type == "salt_pepper":
        salt_pepper_noise = tf.random.uniform(tf.shape(data), minval=0, maxval=1)
        salt_mask = tf.cast(salt_pepper_noise < noise_level / 2, tf.float32)
        pepper_mask = tf.cast(salt_pepper_noise > 1 - (noise_level / 2), tf.float32)
        return data * (1 - salt_mask - pepper_mask) + salt_mask - pepper_mask
    else:
        return data  # Default to no noise if the type is unknown



# Define Loss Functions
def squared_loss(y, y_predicted):
    return tf.reduce_mean(tf.square(y - y_predicted))

def absolute_loss(y, y_predicted):
    return tf.reduce_mean(tf.abs(y - y_predicted))

def huber_loss(y, y_predicted, delta=1.0):
    residual = tf.abs(y - y_predicted)
    condition = tf.less(residual, delta)
    return tf.reduce_mean(
        tf.where(condition, 0.5 * tf.square(residual), delta * (residual - 0.5 * delta))
    )

def hybrid_loss(y, y_predicted, alpha=0.5):
    return alpha * absolute_loss(y, y_predicted) + (1 - alpha) * squared_loss(y, y_predicted)

# Experiment Runner Function
def run_experiment(loss_type, learning_rate, num_steps, noise_level, noise_type, use_patience):
  # Generate dataset
    NUM_EXAMPLES = 500
    X = tf.random.normal([NUM_EXAMPLES])
    noise = tf.random.normal([NUM_EXAMPLES])
    y = X * 3 + 2   # True ouputs

    # Apply noise to the dataset
    y_noisy = add_noise(y, noise_level, noise_type)

    # Initialize model parameters
    W = tf.Variable(0.0, dtype=tf.float32, trainable=True)
    b = tf.Variable(0.0, dtype=tf.float32, trainable=True)

    # Define optimizer
    optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

    # Define prediction function
    def prediction(x):
        return W * x + b

    # Training loop
    best_loss = float('inf')
    patience_counter = 0
    patience_threshold = 200 if use_patience else float('inf')
    losses = []

    for i in range(num_steps):
        with tf.GradientTape() as tape:
            yhat = prediction(X) + tf.random.normal([NUM_EXAMPLES], stddev=noise_level)  # Adding noise dynamically
            if loss_type == "MSE":
                loss = squared_loss(y, yhat)
            elif loss_type == "MAE":
                loss = absolute_loss(y, yhat)
            elif loss_type == "Huber":
                loss = huber_loss(y, yhat)
            elif loss_type == "Hybrid":
                loss = hybrid_loss(y, yhat)
            else:
                raise ValueError("Invalid loss function")

        # Compute gradients
        grads = tape.gradient(loss, [W, b])
        if grads[0] is None or grads[1] is None:
            print(f"Warning: No gradients at step {i}. Skipping update.")
            continue

        optimizer.apply_gradients(zip(grads, [W, b]))

        # Track loss
        current_loss = loss.numpy()
        losses.append(current_loss)

        # Patience scheduling (manual learning rate adjustment)
        if current_loss < best_loss:
            best_loss = current_loss
            patience_counter = 0
        else:
            patience_counter += 1

        if patience_counter >= patience_threshold:
            new_lr = optimizer.learning_rate.numpy() * 0.9  # Reduce LR by 10%
            optimizer.learning_rate.assign(new_lr)
            print(f"Reducing learning rate to {new_lr:.6f} at step {i}")
            patience_counter = 0

        # Print progress every 500 steps
        if i % 500 == 0:
            print(f"Step {i}, Loss: {current_loss:.4f}, W: {W.numpy():.4f}, b: {b.numpy():.4f}")

    print(f"Final Model: W = {W.numpy():.4f}, b = {b.numpy():.4f}, Final Loss: {loss.numpy():.4f}")

    # Plot loss curve
    plt.plot(losses, label=f'{loss_type}')
    plt.xlabel('Training Steps')
    plt.ylabel('Loss')
    plt.title(f'Loss Curve ({loss_type})')
    plt.legend()
    plt.show()

    return W.numpy(), b.numpy(), loss.numpy()

# Experiment Configurations
experiment_configs = [
    {"loss_type": "MSE", "learning_rate": 0.001, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.001, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.001, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.001, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.005, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.005, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.005, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.01, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.01, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.01, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.05, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.05, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MSE", "learning_rate": 0.05, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MSE", "learning_rate": 0.05, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},

    {"loss_type": "MAE", "learning_rate": 0.001, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.001, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.001, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.001, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.005, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.005, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.005, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.01, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.01, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.01, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.05, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.05, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "MAE", "learning_rate": 0.05, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "MAE", "learning_rate": 0.05, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},

    {"loss_type": "Huber", "learning_rate": 0.001, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.001, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.001, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.001, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.005, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.005, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.005, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.01, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.01, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.01, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.05, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.05, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Huber", "learning_rate": 0.05, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Huber", "learning_rate": 0.05, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},

    {"loss_type": "Hybrid", "learning_rate": 0.001, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.001, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.001, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.001, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.005, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.005, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.005, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.01, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.005, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.01, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.01, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.05, "num_steps": 1000, "noise_level": 0.1, "noise_type": "gaussian", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.05, "num_steps": 2500, "noise_level": 0.5, "noise_type": "uniform", "use_patience": False},
    {"loss_type": "Hybrid", "learning_rate": 0.05, "num_steps": 3000, "noise_level": 1.0, "noise_type": "salt_pepper", "use_patience": True},
    {"loss_type": "Hybrid", "learning_rate": 0.05, "num_steps": 3500, "noise_level": 2.0, "noise_type": "laplace", "use_patience": True},
]

# Run all experiments
results = []
for config in experiment_configs:
    W_final, b_final, final_loss = run_experiment(**config)
    results.append((config["loss_type"], config["learning_rate"], config["num_steps"], config["noise_type"], W_final, b_final, final_loss))

# Display results
print("\nExperiment Results:")
for res in results:
  print(f"Loss: {res[0]}, LR: {res[1]}, Steps: {res[2]}, Noise: {res[3]}, W: {res[4]:.4f}, b: {res[5]:.4f}, Final Loss: {res[6]:.4f}")
# Out:
# Step 0, Loss: 12.7499, W: 0.0010, b: 0.0010
# Step 500, Loss: 8.4835, W: 0.4820, b: 0.4723
# Final Model: W = 0.9229, b = 0.8814, Final Loss: 5.4454
# Step 0, Loss: 13.9504, W: 0.0010, b: 0.0010
# Step 500, Loss: 9.6725, W: 0.4818, b: 0.4722
# Step 1000, Loss: 6.2786, W: 0.9232, b: 0.8832
# Step 1500, Loss: 3.7463, W: 1.3265, b: 1.2325
# Step 2000, Loss: 2.3453, W: 1.6918, b: 1.5168
# Final Model: W = 2.0171, b = 1.7311, Final Loss: 1.3816
# Step 0, Loss: 13.2612, W: 0.0010, b: 0.0010
# Step 500, Loss: 8.9918, W: 0.4819, b: 0.4726
# Step 1000, Loss: 6.2095, W: 0.9241, b: 0.8819
# Step 1500, Loss: 4.0581, W: 1.3285, b: 1.2283
# Step 2000, Loss: 2.8446, W: 1.6950, b: 1.5081
# Step 2500, Loss: 1.8713, W: 2.0205, b: 1.7191
# Final Model: W = 2.3038, b = 1.8618, Final Loss: 1.3596
# Step 0, Loss: 16.7130, W: 0.0010, b: 0.0010
# Step 500, Loss: 12.8239, W: 0.4813, b: 0.4717
# Step 1000, Loss: 9.5807, W: 0.9233, b: 0.8828
# Step 1500, Loss: 7.4853, W: 1.3267, b: 1.2320
# Step 2000, Loss: 5.7982, W: 1.6914, b: 1.5148
# Step 2500, Loss: 5.1039, W: 2.0165, b: 1.7292
# Step 3000, Loss: 4.5156, W: 2.2993, b: 1.8747
# Reducing learning rate to 0.000900 at step 3303
# Final Model: W = 2.5236, b = 1.9563, Final Loss: 3.9494
# Step 0, Loss: 14.0738, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.2816, W: 1.9683, b: 1.6870
# Final Model: W = 2.8038, b = 1.9965, Final Loss: 0.0529
# Step 0, Loss: 13.2033, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.3027, W: 1.9665, b: 1.6928
# Step 1000, Loss: 0.2444, W: 2.8009, b: 1.9995
# Step 1500, Loss: 0.2574, W: 2.9825, b: 2.0026
# Step 2000, Loss: 0.2645, W: 3.0011, b: 2.0012
# Final Model: W = 3.0015, b = 2.0002, Final Loss: 0.2816
# Step 0, Loss: 13.9557, W: 0.0050, b: 0.0050
# Step 500, Loss: 2.0563, W: 1.9673, b: 1.6877
# Step 1000, Loss: 1.0123, W: 2.8022, b: 1.9984
# Step 1500, Loss: 0.9463, W: 2.9834, b: 2.0011
# Reducing learning rate to 0.004500 at step 1545
# Reducing learning rate to 0.004050 at step 1789
# Reducing learning rate to 0.003645 at step 1989
# Step 2000, Loss: 0.9943, W: 2.9987, b: 1.9965
# Reducing learning rate to 0.003280 at step 2189
# Reducing learning rate to 0.002952 at step 2389
# Step 2500, Loss: 0.9593, W: 2.9991, b: 1.9966
# Reducing learning rate to 0.002657 at step 2589
# Reducing learning rate to 0.002391 at step 2789
# Reducing learning rate to 0.002152 at step 2989
# Final Model: W = 2.9982, b = 1.9942, Final Loss: 1.0331
# Step 0, Loss: 16.9782, W: 0.0050, b: 0.0050
# Step 500, Loss: 5.3844, W: 1.9738, b: 1.6731
# Reducing learning rate to 0.004500 at step 785
# Step 1000, Loss: 3.9073, W: 2.7986, b: 1.9836
# Reducing learning rate to 0.004050 at step 1468
# Step 1500, Loss: 3.7210, W: 2.9796, b: 2.0026
# Reducing learning rate to 0.003645 at step 1849
# Step 2000, Loss: 4.0232, W: 2.9974, b: 1.9953
# Reducing learning rate to 0.003280 at step 2049
# Reducing learning rate to 0.002952 at step 2249
# Reducing learning rate to 0.002657 at step 2449
# Step 2500, Loss: 4.1855, W: 3.0018, b: 2.0102
# Reducing learning rate to 0.002391 at step 2649
# Step 3000, Loss: 4.2412, W: 2.9976, b: 2.0145
# Reducing learning rate to 0.002152 at step 3029
# Reducing learning rate to 0.001937 at step 3229
# Reducing learning rate to 0.001743 at step 3429
# Final Model: W = 2.9939, b = 2.0010, Final Loss: 3.8014
# Step 0, Loss: 12.4296, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.0459, W: 2.8071, b: 1.9908
# Final Model: W = 2.9987, b = 2.0004, Final Loss: 0.0107
# Step 0, Loss: 13.6650, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.5283, W: 1.9642, b: 1.6943
# Step 1000, Loss: 0.3215, W: 2.7989, b: 2.0036
# Step 1500, Loss: 0.2457, W: 2.9804, b: 2.0035
# Step 2000, Loss: 0.2361, W: 2.9988, b: 1.9986
# Final Model: W = 3.0013, b = 1.9995, Final Loss: 0.2451
# Step 0, Loss: 13.8410, W: 0.0100, b: 0.0100
# Step 500, Loss: 1.1136, W: 2.8147, b: 1.9781
# Step 1000, Loss: 0.8829, W: 3.0017, b: 1.9948
# Reducing learning rate to 0.009000 at step 1258
# Reducing learning rate to 0.008100 at step 1458
# Step 1500, Loss: 1.0065, W: 3.0006, b: 1.9971
# Reducing learning rate to 0.007290 at step 1658
# Reducing learning rate to 0.006561 at step 1858
# Step 2000, Loss: 0.9766, W: 2.9919, b: 2.0031
# Reducing learning rate to 0.005905 at step 2058
# Reducing learning rate to 0.005314 at step 2258
# Reducing learning rate to 0.004783 at step 2458
# Step 2500, Loss: 1.0585, W: 2.9952, b: 2.0051
# Reducing learning rate to 0.004305 at step 2658
# Final Model: W = 2.9982, b = 1.9957, Final Loss: 0.9742
# Step 0, Loss: 16.0954, W: 0.0100, b: 0.0100
# Step 500, Loss: 4.2636, W: 2.8191, b: 1.9830
# Reducing learning rate to 0.009000 at step 872
# Step 1000, Loss: 4.0748, W: 2.9973, b: 1.9968
# Reducing learning rate to 0.008100 at step 1220
# Reducing learning rate to 0.007290 at step 1448
# Step 1500, Loss: 3.9552, W: 2.9868, b: 1.9940
# Reducing learning rate to 0.006561 at step 1648
# Reducing learning rate to 0.005905 at step 1848
# Step 2000, Loss: 4.0480, W: 3.0021, b: 1.9961
# Reducing learning rate to 0.005314 at step 2048
# Reducing learning rate to 0.004783 at step 2248
# Reducing learning rate to 0.004305 at step 2448
# Step 2500, Loss: 4.0817, W: 2.9974, b: 2.0134
# Reducing learning rate to 0.003874 at step 2648
# Reducing learning rate to 0.003487 at step 2848
# Step 3000, Loss: 4.6021, W: 2.9996, b: 2.0061
# Reducing learning rate to 0.003138 at step 3048
# Reducing learning rate to 0.002824 at step 3299
# Reducing learning rate to 0.002542 at step 3499
# Final Model: W = 2.9874, b = 2.0026, Final Loss: 4.1092
# Step 0, Loss: 13.0167, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.0107, W: 3.0023, b: 2.0017
# Final Model: W = 3.0002, b = 1.9995, Final Loss: 0.0104
# Step 0, Loss: 12.9425, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.2491, W: 2.9946, b: 2.0012
# Step 1000, Loss: 0.2482, W: 2.9907, b: 2.0101
# Step 1500, Loss: 0.2635, W: 3.0115, b: 1.9914
# Step 2000, Loss: 0.2461, W: 2.9961, b: 1.9896
# Final Model: W = 3.0036, b = 1.9954, Final Loss: 0.2632
# Step 0, Loss: 15.4088, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 476
# Step 500, Loss: 0.8482, W: 2.9915, b: 1.9972
# Reducing learning rate to 0.040500 at step 676
# Reducing learning rate to 0.036450 at step 876
# Step 1000, Loss: 0.8836, W: 2.9931, b: 2.0173
# Reducing learning rate to 0.032805 at step 1076
# Reducing learning rate to 0.029524 at step 1276
# Reducing learning rate to 0.026572 at step 1476
# Step 1500, Loss: 1.0591, W: 3.0045, b: 2.0208
# Reducing learning rate to 0.023915 at step 1676
# Reducing learning rate to 0.021523 at step 1876
# Step 2000, Loss: 0.9512, W: 2.9995, b: 2.0076
# Reducing learning rate to 0.019371 at step 2076
# Reducing learning rate to 0.017434 at step 2276
# Reducing learning rate to 0.015691 at step 2476
# Step 2500, Loss: 0.9188, W: 2.9933, b: 2.0091
# Reducing learning rate to 0.014121 at step 2676
# Reducing learning rate to 0.012709 at step 2876
# Final Model: W = 3.0070, b = 2.0029, Final Loss: 1.0264
# Step 0, Loss: 16.8175, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 328
# Step 500, Loss: 4.5052, W: 2.9684, b: 2.0420
# Reducing learning rate to 0.040500 at step 528
# Reducing learning rate to 0.036450 at step 885
# Step 1000, Loss: 4.0376, W: 3.0155, b: 1.9751
# Reducing learning rate to 0.032805 at step 1085
# Reducing learning rate to 0.029524 at step 1285
# Reducing learning rate to 0.026572 at step 1487
# Step 1500, Loss: 4.0198, W: 2.9873, b: 1.9876
# Reducing learning rate to 0.023915 at step 1687
# Reducing learning rate to 0.021523 at step 1887
# Step 2000, Loss: 4.0282, W: 3.0231, b: 1.9756
# Reducing learning rate to 0.019371 at step 2087
# Reducing learning rate to 0.017434 at step 2287
# Reducing learning rate to 0.015691 at step 2487
# Step 2500, Loss: 3.9957, W: 2.9992, b: 2.0038
# Reducing learning rate to 0.014121 at step 2687
# Reducing learning rate to 0.012709 at step 2887
# Step 3000, Loss: 3.7299, W: 3.0280, b: 2.0103
# Reducing learning rate to 0.011438 at step 3087
# Reducing learning rate to 0.010295 at step 3287
# Reducing learning rate to 0.009265 at step 3487
# Final Model: W = 2.9797, b = 1.9825, Final Loss: 4.1105
# Step 0, Loss: 2.9236, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.3440, W: 0.5047, b: 0.4942
# Final Model: W = 1.0166, b = 0.9652, Final Loss: 1.7834
# Step 0, Loss: 2.9156, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.3760, W: 0.5051, b: 0.4895
# Step 1000, Loss: 1.8498, W: 1.0169, b: 0.9485
# Step 1500, Loss: 1.3606, W: 1.5327, b: 1.3653
# Step 2000, Loss: 0.9354, W: 2.0438, b: 1.7109
# Final Model: W = 2.5154, b = 1.9285, Final Loss: 0.5495
# Step 0, Loss: 3.0520, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.4986, W: 0.5035, b: 0.4897
# Step 1000, Loss: 2.0056, W: 1.0089, b: 0.9486
# Step 1500, Loss: 1.5568, W: 1.5104, b: 1.3635
# Step 2000, Loss: 1.1464, W: 1.9887, b: 1.7034
# Step 2500, Loss: 0.8818, W: 2.4060, b: 1.9206
# Final Model: W = 2.7090, b = 1.9979, Final Loss: 0.8388
# Step 0, Loss: 3.4471, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.8807, W: 0.4983, b: 0.4847
# Step 1000, Loss: 2.5018, W: 0.9831, b: 0.9322
# Step 1500, Loss: 2.0331, W: 1.4448, b: 1.3259
# Step 2000, Loss: 1.8414, W: 1.8671, b: 1.6388
# Reducing learning rate to 0.000900 at step 2365
# Step 2500, Loss: 1.7049, W: 2.2237, b: 1.8417
# Reducing learning rate to 0.000810 at step 2723
# Step 3000, Loss: 1.6680, W: 2.4782, b: 1.9447
# Reducing learning rate to 0.000729 at step 3252
# Final Model: W = 2.6687, b = 1.9863, Final Loss: 1.6844
# Step 0, Loss: 2.9832, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.3441, W: 2.5978, b: 1.9877
# Final Model: W = 2.9982, b = 2.0020, Final Loss: 0.0809
# Step 0, Loss: 2.8470, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.5262, W: 2.5255, b: 1.9444
# Step 1000, Loss: 0.3906, W: 3.0012, b: 2.0077
# Step 1500, Loss: 0.3686, W: 3.0003, b: 1.9998
# Step 2000, Loss: 0.3853, W: 2.9982, b: 2.0033
# Final Model: W = 3.0000, b = 1.9935, Final Loss: 0.3912
# Step 0, Loss: 3.0526, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.9161, W: 2.4005, b: 1.8812
# Reducing learning rate to 0.004500 at step 964
# Step 1000, Loss: 0.8138, W: 2.9949, b: 2.0037
# Reducing learning rate to 0.004050 at step 1184
# Reducing learning rate to 0.003645 at step 1384
# Step 1500, Loss: 0.8284, W: 3.0039, b: 2.0085
# Reducing learning rate to 0.003280 at step 1584
# Reducing learning rate to 0.002952 at step 1914
# Step 2000, Loss: 0.8141, W: 3.0024, b: 2.0032
# Reducing learning rate to 0.002657 at step 2114
# Reducing learning rate to 0.002391 at step 2314
# Step 2500, Loss: 0.7740, W: 3.0017, b: 2.0058
# Reducing learning rate to 0.002152 at step 2514
# Reducing learning rate to 0.001937 at step 2842
# Final Model: W = 3.0003, b = 2.0042, Final Loss: 0.7806
# Step 0, Loss: 3.4429, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.6813, W: 2.2230, b: 1.7999
# Reducing learning rate to 0.004500 at step 926
# Step 1000, Loss: 1.6801, W: 2.9371, b: 1.9911
# Reducing learning rate to 0.004050 at step 1144
# Reducing learning rate to 0.003645 at step 1344
# Step 1500, Loss: 1.6464, W: 3.0011, b: 2.0003
# Reducing learning rate to 0.003280 at step 1544
# Reducing learning rate to 0.002952 at step 1744
# Reducing learning rate to 0.002657 at step 1944
# Step 2000, Loss: 1.6129, W: 2.9964, b: 2.0067
# Reducing learning rate to 0.002391 at step 2144
# Reducing learning rate to 0.002152 at step 2344
# Step 2500, Loss: 1.6452, W: 3.0056, b: 1.9923
# Reducing learning rate to 0.001937 at step 2544
# Reducing learning rate to 0.001743 at step 2744
# Reducing learning rate to 0.001569 at step 2944
# Step 3000, Loss: 1.6361, W: 2.9996, b: 1.9960
# Reducing learning rate to 0.001412 at step 3144
# Reducing learning rate to 0.001271 at step 3344
# Final Model: W = 2.9961, b = 2.0072, Final Loss: 1.6573
# Step 0, Loss: 3.0320, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.0794, W: 3.0005, b: 2.0001
# Final Model: W = 3.0018, b = 2.0016, Final Loss: 0.0806
# Step 0, Loss: 3.1270, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.5370, W: 2.5186, b: 1.9616
# Step 1000, Loss: 0.4315, W: 2.9931, b: 2.0021
# Step 1500, Loss: 0.3907, W: 2.9990, b: 1.9978
# Step 2000, Loss: 0.3957, W: 2.9974, b: 1.9997
# Final Model: W = 3.0093, b = 2.0036, Final Loss: 0.3847
# Step 0, Loss: 2.8921, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.8082, W: 2.9907, b: 2.0095
# Reducing learning rate to 0.009000 at step 758
# Reducing learning rate to 0.008100 at step 958
# Step 1000, Loss: 0.7621, W: 3.0075, b: 2.0019
# Reducing learning rate to 0.007290 at step 1158
# Reducing learning rate to 0.006561 at step 1358
# Step 1500, Loss: 0.8064, W: 3.0017, b: 2.0019
# Reducing learning rate to 0.005905 at step 1558
# Reducing learning rate to 0.005314 at step 1758
# Reducing learning rate to 0.004783 at step 1958
# Step 2000, Loss: 0.8314, W: 3.0078, b: 2.0063
# Reducing learning rate to 0.004305 at step 2158
# Reducing learning rate to 0.003874 at step 2358
# Step 2500, Loss: 0.8283, W: 2.9907, b: 2.0209
# Reducing learning rate to 0.003487 at step 2558
# Reducing learning rate to 0.003138 at step 2758
# Final Model: W = 3.0059, b = 1.9855, Final Loss: 0.8271
# Step 0, Loss: 3.2271, W: 0.0100, b: 0.0100
# Step 500, Loss: 1.4911, W: 2.9686, b: 2.0071
# Reducing learning rate to 0.009000 at step 594
# Reducing learning rate to 0.008100 at step 935
# Step 1000, Loss: 1.5700, W: 2.9862, b: 1.9926
# Reducing learning rate to 0.007290 at step 1135
# Reducing learning rate to 0.006561 at step 1490
# Step 1500, Loss: 1.7271, W: 3.0052, b: 2.0011
# Reducing learning rate to 0.005905 at step 1690
# Reducing learning rate to 0.005314 at step 1890
# Step 2000, Loss: 1.5227, W: 3.0132, b: 1.9883
# Reducing learning rate to 0.004783 at step 2090
# Reducing learning rate to 0.004305 at step 2290
# Reducing learning rate to 0.003874 at step 2490
# Step 2500, Loss: 1.6917, W: 3.0015, b: 1.9922
# Reducing learning rate to 0.003487 at step 2690
# Reducing learning rate to 0.003138 at step 2890
# Step 3000, Loss: 1.6656, W: 3.0046, b: 2.0008
# Reducing learning rate to 0.002824 at step 3090
# Reducing learning rate to 0.002542 at step 3290
# Reducing learning rate to 0.002288 at step 3490
# Final Model: W = 2.9997, b = 1.9940, Final Loss: 1.4876
# Step 0, Loss: 2.9142, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.0797, W: 3.0009, b: 1.9970
# Final Model: W = 2.9878, b = 1.9967, Final Loss: 0.0818
# Step 0, Loss: 3.0111, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.4069, W: 2.9944, b: 2.0201
# Step 1000, Loss: 0.4076, W: 3.0142, b: 1.9995
# Step 1500, Loss: 0.3898, W: 3.0148, b: 1.9774
# Step 2000, Loss: 0.3829, W: 2.9952, b: 2.0426
# Final Model: W = 2.9739, b = 1.9878, Final Loss: 0.3775
# Step 0, Loss: 3.0652, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 289
# Step 500, Loss: 0.8438, W: 3.0053, b: 2.0316
# Reducing learning rate to 0.040500 at step 687
# Reducing learning rate to 0.036450 at step 937
# Step 1000, Loss: 0.8061, W: 2.9938, b: 2.0557
# Reducing learning rate to 0.032805 at step 1137
# Reducing learning rate to 0.029524 at step 1337
# Step 1500, Loss: 0.8258, W: 2.9567, b: 2.0140
# Reducing learning rate to 0.026572 at step 1537
# Reducing learning rate to 0.023915 at step 1737
# Reducing learning rate to 0.021523 at step 1937
# Step 2000, Loss: 0.8411, W: 2.9831, b: 1.9545
# Reducing learning rate to 0.019371 at step 2137
# Reducing learning rate to 0.017434 at step 2337
# Step 2500, Loss: 0.8202, W: 3.0029, b: 1.9878
# Reducing learning rate to 0.015691 at step 2537
# Reducing learning rate to 0.014121 at step 2737
# Reducing learning rate to 0.012709 at step 2937
# Final Model: W = 2.9942, b = 2.0101, Final Loss: 0.8119
# Step 0, Loss: 3.2972, W: 0.0500, b: 0.0500
# Step 500, Loss: 1.5927, W: 3.0175, b: 1.9592
# Reducing learning rate to 0.045000 at step 534
# Reducing learning rate to 0.040500 at step 734
# Reducing learning rate to 0.036450 at step 934
# Step 1000, Loss: 1.6666, W: 2.9596, b: 2.0333
# Reducing learning rate to 0.032805 at step 1134
# Reducing learning rate to 0.029524 at step 1404
# Step 1500, Loss: 1.5944, W: 3.0555, b: 1.9567
# Reducing learning rate to 0.026572 at step 1604
# Reducing learning rate to 0.023915 at step 1804
# Step 2000, Loss: 1.5217, W: 2.9616, b: 1.9964
# Reducing learning rate to 0.021523 at step 2004
# Reducing learning rate to 0.019371 at step 2204
# Reducing learning rate to 0.017434 at step 2404
# Step 2500, Loss: 1.5828, W: 3.0112, b: 1.9859
# Reducing learning rate to 0.015691 at step 2604
# Reducing learning rate to 0.014121 at step 2804
# Step 3000, Loss: 1.5580, W: 2.9807, b: 2.0075
# Reducing learning rate to 0.012709 at step 3004
# Reducing learning rate to 0.011438 at step 3204
# Reducing learning rate to 0.010295 at step 3404
# Final Model: W = 3.0184, b = 1.9238, Final Loss: 1.7142
# Step 0, Loss: 2.4550, W: 0.0010, b: 0.0010
# Step 500, Loss: 1.9053, W: 0.5047, b: 0.4889
# Final Model: W = 1.0139, b = 0.9455, Final Loss: 1.3836
# Step 0, Loss: 2.3309, W: 0.0010, b: 0.0010
# Step 500, Loss: 1.8186, W: 0.5043, b: 0.4910
# Step 1000, Loss: 1.3027, W: 1.0130, b: 0.9535
# Step 1500, Loss: 0.8348, W: 1.5212, b: 1.3714
# Step 2000, Loss: 0.4917, W: 2.0109, b: 1.7111
# Final Model: W = 2.4361, b = 1.9163, Final Loss: 0.2477
# Step 0, Loss: 2.6688, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.1583, W: 0.5025, b: 0.4898
# Step 1000, Loss: 1.5922, W: 1.0039, b: 0.9512
# Step 1500, Loss: 1.1389, W: 1.4977, b: 1.3644
# Step 2000, Loss: 0.7897, W: 1.9623, b: 1.7024
# Step 2500, Loss: 0.5880, W: 2.3628, b: 1.9171
# Final Model: W = 2.6605, b = 2.0015, Final Loss: 0.5078
# Step 0, Loss: 2.8059, W: 0.0010, b: 0.0010
# Step 500, Loss: 2.3379, W: 0.4980, b: 0.4852
# Step 1000, Loss: 1.9749, W: 0.9822, b: 0.9290
# Step 1500, Loss: 1.6299, W: 1.4428, b: 1.3123
# Reducing learning rate to 0.000900 at step 1900
# Step 2000, Loss: 1.4318, W: 1.8516, b: 1.6128
# Reducing learning rate to 0.000810 at step 2106
# Step 2500, Loss: 1.2949, W: 2.1594, b: 1.7938
# Step 3000, Loss: 1.2741, W: 2.4195, b: 1.9150
# Reducing learning rate to 0.000729 at step 3491
# Final Model: W = 2.6281, b = 1.9714, Final Loss: 1.2520
# Step 0, Loss: 2.4479, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.1386, W: 2.4836, b: 1.9264
# Final Model: W = 2.9973, b = 1.9997, Final Loss: 0.0047
# Step 0, Loss: 2.4248, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.2446, W: 2.4530, b: 1.8958
# Step 1000, Loss: 0.1154, W: 2.9977, b: 1.9961
# Step 1500, Loss: 0.1193, W: 2.9964, b: 1.9972
# Step 2000, Loss: 0.1167, W: 2.9986, b: 2.0058
# Final Model: W = 3.0000, b = 2.0062, Final Loss: 0.1318
# Step 0, Loss: 2.4342, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.5808, W: 2.3654, b: 1.8339
# Reducing learning rate to 0.004500 at step 919
# Step 1000, Loss: 0.4038, W: 2.9947, b: 1.9933
# Reducing learning rate to 0.004050 at step 1119
# Reducing learning rate to 0.003645 at step 1319
# Step 1500, Loss: 0.4158, W: 3.0019, b: 2.0062
# Reducing learning rate to 0.003280 at step 1519
# Reducing learning rate to 0.002952 at step 1719
# Reducing learning rate to 0.002657 at step 1919
# Step 2000, Loss: 0.3856, W: 3.0046, b: 1.9915
# Reducing learning rate to 0.002391 at step 2119
# Reducing learning rate to 0.002152 at step 2319
# Step 2500, Loss: 0.3971, W: 2.9965, b: 1.9983
# Reducing learning rate to 0.001937 at step 2519
# Reducing learning rate to 0.001743 at step 2719
# Final Model: W = 2.9957, b = 2.0059, Final Loss: 0.4328
# Step 0, Loss: 2.6399, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.2914, W: 2.2031, b: 1.8027
# Step 1000, Loss: 1.1474, W: 2.9337, b: 2.0060
# Reducing learning rate to 0.004500 at step 1066
# Step 1500, Loss: 1.1470, W: 2.9921, b: 1.9936
# Reducing learning rate to 0.004050 at step 1527
# Reducing learning rate to 0.003645 at step 1727
# Step 2000, Loss: 1.2168, W: 2.9962, b: 2.0072
# Reducing learning rate to 0.003280 at step 2003
# Reducing learning rate to 0.002952 at step 2213
# Reducing learning rate to 0.002657 at step 2413
# Step 2500, Loss: 1.1951, W: 2.9941, b: 1.9910
# Reducing learning rate to 0.002391 at step 2613
# Reducing learning rate to 0.002152 at step 2813
# Step 3000, Loss: 1.2216, W: 2.9865, b: 2.0072
# Reducing learning rate to 0.001937 at step 3013
# Reducing learning rate to 0.001743 at step 3213
# Reducing learning rate to 0.001569 at step 3413
# Final Model: W = 3.0048, b = 2.0011, Final Loss: 1.1514
# Step 0, Loss: 2.3269, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.0046, W: 2.9984, b: 1.9987
# Final Model: W = 3.0004, b = 1.9998, Final Loss: 0.0050
# Step 0, Loss: 2.5158, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.2514, W: 2.4575, b: 1.9237
# Step 1000, Loss: 0.1169, W: 2.9962, b: 2.0035
# Step 1500, Loss: 0.1316, W: 3.0011, b: 1.9999
# Step 2000, Loss: 0.1304, W: 3.0019, b: 2.0007
# Final Model: W = 2.9980, b = 1.9965, Final Loss: 0.1262
# Step 0, Loss: 2.3923, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.4101, W: 3.0022, b: 2.0102
# Reducing learning rate to 0.009000 at step 704
# Reducing learning rate to 0.008100 at step 904
# Step 1000, Loss: 0.4194, W: 3.0019, b: 1.9997
# Reducing learning rate to 0.007290 at step 1104
# Reducing learning rate to 0.006561 at step 1304
# Step 1500, Loss: 0.4238, W: 2.9985, b: 2.0130
# Reducing learning rate to 0.005905 at step 1504
# Reducing learning rate to 0.005314 at step 1704
# Reducing learning rate to 0.004783 at step 1904
# Step 2000, Loss: 0.4171, W: 2.9937, b: 2.0016
# Reducing learning rate to 0.004305 at step 2104
# Reducing learning rate to 0.003874 at step 2304
# Step 2500, Loss: 0.4510, W: 2.9962, b: 2.0071
# Reducing learning rate to 0.003487 at step 2504
# Reducing learning rate to 0.003138 at step 2704
# Reducing learning rate to 0.002824 at step 2904
# Final Model: W = 3.0015, b = 1.9952, Final Loss: 0.4304
# Step 0, Loss: 2.7459, W: 0.0100, b: 0.0100
# Step 500, Loss: 1.1930, W: 2.9471, b: 1.9857
# Reducing learning rate to 0.009000 at step 749
# Step 1000, Loss: 1.1491, W: 3.0022, b: 1.9857
# Reducing learning rate to 0.008100 at step 1086
# Reducing learning rate to 0.007290 at step 1286
# Reducing learning rate to 0.006561 at step 1486
# Step 1500, Loss: 1.1095, W: 3.0113, b: 1.9967
# Reducing learning rate to 0.005905 at step 1756
# Reducing learning rate to 0.005314 at step 1956
# Step 2000, Loss: 1.2180, W: 3.0018, b: 1.9981
# Reducing learning rate to 0.004783 at step 2156
# Reducing learning rate to 0.004305 at step 2356
# Step 2500, Loss: 1.1708, W: 2.9901, b: 1.9948
# Reducing learning rate to 0.003874 at step 2556
# Reducing learning rate to 0.003487 at step 2756
# Step 3000, Loss: 1.2244, W: 2.9926, b: 1.9934
# Reducing learning rate to 0.003138 at step 3025
# Reducing learning rate to 0.002824 at step 3225
# Reducing learning rate to 0.002542 at step 3425
# Final Model: W = 2.9870, b = 1.9883, Final Loss: 1.1716
# Step 0, Loss: 2.3890, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.0045, W: 2.9998, b: 1.9969
# Final Model: W = 2.9982, b = 1.9977, Final Loss: 0.0053
# Step 0, Loss: 2.5010, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.1117, W: 2.9910, b: 1.9824
# Step 1000, Loss: 0.1059, W: 2.9883, b: 2.0161
# Step 1500, Loss: 0.1316, W: 3.0166, b: 2.0165
# Step 2000, Loss: 0.1218, W: 3.0097, b: 1.9902
# Final Model: W = 3.0011, b = 1.9861, Final Loss: 0.1348
# Step 0, Loss: 2.6625, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 434
# Step 500, Loss: 0.4392, W: 2.9998, b: 1.9926
# Reducing learning rate to 0.040500 at step 634
# Step 1000, Loss: 0.3991, W: 2.9891, b: 1.9949
# Reducing learning rate to 0.036450 at step 1483
# Step 1500, Loss: 0.4134, W: 2.9712, b: 1.9918
# Reducing learning rate to 0.032805 at step 1683
# Reducing learning rate to 0.029524 at step 1883
# Step 2000, Loss: 0.3877, W: 3.0146, b: 2.0005
# Reducing learning rate to 0.026572 at step 2083
# Reducing learning rate to 0.023915 at step 2283
# Reducing learning rate to 0.021523 at step 2483
# Step 2500, Loss: 0.4050, W: 3.0089, b: 1.9705
# Reducing learning rate to 0.019371 at step 2683
# Reducing learning rate to 0.017434 at step 2883
# Final Model: W = 2.9936, b = 2.0339, Final Loss: 0.3875
# Step 0, Loss: 2.8186, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 267
# Reducing learning rate to 0.040500 at step 467
# Step 500, Loss: 1.0918, W: 2.9642, b: 1.9526
# Reducing learning rate to 0.036450 at step 758
# Reducing learning rate to 0.032805 at step 958
# Step 1000, Loss: 1.1951, W: 3.0022, b: 1.9925
# Reducing learning rate to 0.029524 at step 1251
# Reducing learning rate to 0.026572 at step 1451
# Step 1500, Loss: 1.1275, W: 3.0099, b: 1.9503
# Reducing learning rate to 0.023915 at step 1651
# Reducing learning rate to 0.021523 at step 1851
# Step 2000, Loss: 1.1628, W: 2.9512, b: 2.0390
# Reducing learning rate to 0.019371 at step 2051
# Reducing learning rate to 0.017434 at step 2251
# Reducing learning rate to 0.015691 at step 2451
# Step 2500, Loss: 1.1608, W: 3.0019, b: 2.0148
# Reducing learning rate to 0.014121 at step 2651
# Reducing learning rate to 0.012709 at step 2851
# Step 3000, Loss: 1.1171, W: 3.0022, b: 1.9968
# Reducing learning rate to 0.011438 at step 3051
# Reducing learning rate to 0.010295 at step 3251
# Reducing learning rate to 0.009265 at step 3451
# Final Model: W = 2.9959, b = 2.0242, Final Loss: 1.1379
# Step 0, Loss: 8.7154, W: 0.0010, b: 0.0010
# Step 500, Loss: 6.0387, W: 0.4842, b: 0.4743
# Final Model: W = 0.9322, b = 0.8901, Final Loss: 4.0522
# Step 0, Loss: 7.6356, W: 0.0010, b: 0.0010
# Step 500, Loss: 5.2313, W: 0.4844, b: 0.4742
# Step 1000, Loss: 3.5516, W: 0.9337, b: 0.8895
# Step 1500, Loss: 2.3125, W: 1.3515, b: 1.2447
# Step 2000, Loss: 1.5231, W: 1.7368, b: 1.5353
# Final Model: W = 2.0868, b = 1.7536, Final Loss: 0.9872
# Step 0, Loss: 8.3287, W: 0.0010, b: 0.0010
# Step 500, Loss: 5.7218, W: 0.4840, b: 0.4724
# Step 1000, Loss: 4.0244, W: 0.9331, b: 0.8821
# Step 1500, Loss: 2.9289, W: 1.3495, b: 1.2312
# Step 2000, Loss: 2.1001, W: 1.7321, b: 1.5139
# Step 2500, Loss: 1.5299, W: 2.0768, b: 1.7206
# Final Model: W = 2.3744, b = 1.8615, Final Loss: 1.1818
# Step 0, Loss: 9.9547, W: 0.0010, b: 0.0010
# Step 500, Loss: 7.9072, W: 0.4843, b: 0.4719
# Step 1000, Loss: 5.7256, W: 0.9311, b: 0.8806
# Step 1500, Loss: 5.0544, W: 1.3434, b: 1.2253
# Step 2000, Loss: 4.0926, W: 1.7191, b: 1.4951
# Reducing learning rate to 0.000900 at step 2420
# Step 2500, Loss: 2.9943, W: 2.0509, b: 1.6958
# Step 3000, Loss: 2.9718, W: 2.3155, b: 1.8238
# Reducing learning rate to 0.000810 at step 3218
# Reducing learning rate to 0.000729 at step 3463
# Final Model: W = 2.5286, b = 1.9022, Final Loss: 3.0361
# Step 0, Loss: 7.9444, W: 0.0050, b: 0.0050
# Step 500, Loss: 0.9236, W: 2.0469, b: 1.7133
# Final Model: W = 2.9862, b = 1.9998, Final Loss: 0.0462
# Step 0, Loss: 7.8837, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.0541, W: 2.0407, b: 1.7156
# Step 1000, Loss: 0.3275, W: 2.9112, b: 1.9972
# Step 1500, Loss: 0.3105, W: 3.0000, b: 1.9963
# Step 2000, Loss: 0.3310, W: 3.0013, b: 1.9967
# Final Model: W = 2.9974, b = 2.0059, Final Loss: 0.3341
# Step 0, Loss: 8.1105, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.5253, W: 2.0333, b: 1.6666
# Step 1000, Loss: 0.8613, W: 2.8765, b: 1.9700
# Reducing learning rate to 0.004500 at step 1162
# Reducing learning rate to 0.004050 at step 1436
# Step 1500, Loss: 0.8441, W: 2.9930, b: 1.9978
# Reducing learning rate to 0.003645 at step 1636
# Reducing learning rate to 0.003280 at step 1836
# Step 2000, Loss: 0.8810, W: 3.0008, b: 2.0077
# Reducing learning rate to 0.002952 at step 2036
# Reducing learning rate to 0.002657 at step 2236
# Reducing learning rate to 0.002391 at step 2436
# Step 2500, Loss: 0.8837, W: 2.9960, b: 1.9976
# Reducing learning rate to 0.002152 at step 2636
# Reducing learning rate to 0.001937 at step 2836
# Final Model: W = 2.9976, b = 1.9998, Final Loss: 0.8477
# Step 0, Loss: 10.4778, W: 0.0050, b: 0.0050
# Step 500, Loss: 3.5449, W: 1.9983, b: 1.6969
# Step 1000, Loss: 2.7409, W: 2.8370, b: 2.0026
# Reducing learning rate to 0.004500 at step 1187
# Reducing learning rate to 0.004050 at step 1387
# Step 1500, Loss: 2.9756, W: 2.9833, b: 2.0131
# Reducing learning rate to 0.003645 at step 1587
# Reducing learning rate to 0.003280 at step 1787
# Reducing learning rate to 0.002952 at step 1987
# Step 2000, Loss: 2.9123, W: 2.9963, b: 2.0011
# Reducing learning rate to 0.002657 at step 2187
# Reducing learning rate to 0.002391 at step 2387
# Step 2500, Loss: 3.1518, W: 3.0014, b: 1.9960
# Reducing learning rate to 0.002152 at step 2587
# Reducing learning rate to 0.001937 at step 2787
# Reducing learning rate to 0.001743 at step 2987
# Step 3000, Loss: 2.7898, W: 2.9972, b: 1.9903
# Reducing learning rate to 0.001569 at step 3207
# Reducing learning rate to 0.001412 at step 3407
# Final Model: W = 2.9961, b = 1.9908, Final Loss: 2.6269
# Step 0, Loss: 7.2004, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.0453, W: 2.9908, b: 1.9977
# Final Model: W = 3.0003, b = 1.9997, Final Loss: 0.0449
# Step 0, Loss: 8.0750, W: 0.0050, b: 0.0050
# Step 500, Loss: 1.0552, W: 2.0372, b: 1.7159
# Step 1000, Loss: 0.3419, W: 2.9124, b: 1.9972
# Step 1500, Loss: 0.3359, W: 2.9979, b: 1.9982
# Step 2000, Loss: 0.3100, W: 2.9985, b: 2.0000
# Final Model: W = 3.0042, b = 1.9963, Final Loss: 0.2885
# Step 0, Loss: 8.5040, W: 0.0100, b: 0.0100
# Step 500, Loss: 0.8916, W: 2.8719, b: 1.9980
# Reducing learning rate to 0.009000 at step 698
# Step 1000, Loss: 0.8822, W: 3.0026, b: 1.9977
# Reducing learning rate to 0.008100 at step 1059
# Reducing learning rate to 0.007290 at step 1259
# Reducing learning rate to 0.006561 at step 1459
# Step 1500, Loss: 0.9650, W: 2.9917, b: 2.0002
# Reducing learning rate to 0.005905 at step 1659
# Reducing learning rate to 0.005314 at step 1859
# Step 2000, Loss: 0.9283, W: 3.0052, b: 1.9974
# Reducing learning rate to 0.004783 at step 2059
# Reducing learning rate to 0.004305 at step 2448
# Step 2500, Loss: 0.8160, W: 3.0055, b: 2.0079
# Reducing learning rate to 0.003874 at step 2648
# Reducing learning rate to 0.003487 at step 2848
# Final Model: W = 2.9982, b = 1.9955, Final Loss: 0.9213
# Step 0, Loss: 10.1506, W: 0.0100, b: 0.0100
# Step 500, Loss: 2.8232, W: 2.8412, b: 1.9835
# Reducing learning rate to 0.009000 at step 808
# Step 1000, Loss: 2.8784, W: 2.9997, b: 1.9896
# Reducing learning rate to 0.008100 at step 1118
# Reducing learning rate to 0.007290 at step 1318
# Step 1500, Loss: 2.9392, W: 3.0020, b: 2.0037
# Reducing learning rate to 0.006561 at step 1518
# Reducing learning rate to 0.005905 at step 1718
# Reducing learning rate to 0.005314 at step 1936
# Step 2000, Loss: 2.9124, W: 3.0108, b: 1.9997
# Reducing learning rate to 0.004783 at step 2136
# Reducing learning rate to 0.004305 at step 2336
# Step 2500, Loss: 2.7355, W: 2.9891, b: 2.0185
# Reducing learning rate to 0.003874 at step 2536
# Reducing learning rate to 0.003487 at step 2844
# Step 3000, Loss: 2.6420, W: 3.0203, b: 1.9760
# Reducing learning rate to 0.003138 at step 3044
# Reducing learning rate to 0.002824 at step 3244
# Reducing learning rate to 0.002542 at step 3444
# Final Model: W = 2.9861, b = 1.9960, Final Loss: 2.8182
# Step 0, Loss: 7.2653, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.0440, W: 2.9984, b: 1.9990
# Final Model: W = 2.9996, b = 1.9933, Final Loss: 0.0453
# Step 0, Loss: 8.2358, W: 0.0500, b: 0.0500
# Step 500, Loss: 0.3101, W: 3.0033, b: 1.9948
# Step 1000, Loss: 0.3121, W: 3.0027, b: 2.0124
# Step 1500, Loss: 0.3372, W: 3.0132, b: 2.0098
# Step 2000, Loss: 0.3458, W: 3.0135, b: 1.9907
# Final Model: W = 3.0166, b = 2.0039, Final Loss: 0.3192
# Step 0, Loss: 7.5325, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 353
# Step 500, Loss: 0.9605, W: 2.9981, b: 2.0023
# Reducing learning rate to 0.040500 at step 553
# Reducing learning rate to 0.036450 at step 753
# Reducing learning rate to 0.032805 at step 953
# Step 1000, Loss: 0.8773, W: 2.9890, b: 1.9612
# Reducing learning rate to 0.029524 at step 1153
# Reducing learning rate to 0.026572 at step 1353
# Step 1500, Loss: 0.9169, W: 2.9881, b: 2.0234
# Reducing learning rate to 0.023915 at step 1553
# Reducing learning rate to 0.021523 at step 1753
# Reducing learning rate to 0.019371 at step 1953
# Step 2000, Loss: 0.8587, W: 2.9906, b: 2.0243
# Reducing learning rate to 0.017434 at step 2153
# Reducing learning rate to 0.015691 at step 2353
# Step 2500, Loss: 0.8893, W: 2.9972, b: 2.0053
# Reducing learning rate to 0.014121 at step 2554
# Reducing learning rate to 0.012709 at step 2754
# Reducing learning rate to 0.011438 at step 2954
# Final Model: W = 3.0048, b = 1.9781, Final Loss: 0.9020
# Step 0, Loss: 9.8199, W: 0.0500, b: 0.0500
# Reducing learning rate to 0.045000 at step 321
# Step 500, Loss: 2.8012, W: 3.0066, b: 2.0188
# Reducing learning rate to 0.040500 at step 521
# Reducing learning rate to 0.036450 at step 721
# Reducing learning rate to 0.032805 at step 921
# Step 1000, Loss: 2.8022, W: 2.9967, b: 1.9431
# Reducing learning rate to 0.029524 at step 1121
# Reducing learning rate to 0.026572 at step 1321
# Step 1500, Loss: 2.5227, W: 2.9751, b: 1.9920
# Reducing learning rate to 0.023915 at step 1521
# Reducing learning rate to 0.021523 at step 1721
# Reducing learning rate to 0.019371 at step 1921
# Step 2000, Loss: 2.7177, W: 2.9842, b: 1.9782
# Reducing learning rate to 0.017434 at step 2121
# Reducing learning rate to 0.015691 at step 2321
# Step 2500, Loss: 2.9409, W: 3.0107, b: 1.9929
# Reducing learning rate to 0.014121 at step 2521
# Reducing learning rate to 0.012709 at step 2721
# Reducing learning rate to 0.011438 at step 2921
# Step 3000, Loss: 2.7580, W: 3.0206, b: 2.0126
# Reducing learning rate to 0.010295 at step 3121
# Reducing learning rate to 0.009265 at step 3321
# Final Model: W = 3.0052, b = 2.0113, Final Loss: 2.8034
# Experiment Results:
# Loss: MSE, LR: 0.001, Steps: 1000, Noise: gaussian, W: 0.9229, b: 0.8814, Final Loss: 5.4454
# Loss: MSE, LR: 0.001, Steps: 2500, Noise: uniform, W: 2.0171, b: 1.7311, Final Loss: 1.3816
# Loss: MSE, LR: 0.001, Steps: 3000, Noise: salt_pepper, W: 2.3038, b: 1.8618, Final Loss: 1.3596
# Loss: MSE, LR: 0.001, Steps: 3500, Noise: laplace, W: 2.5236, b: 1.9563, Final Loss: 3.9494
# Loss: MSE, LR: 0.005, Steps: 1000, Noise: gaussian, W: 2.8038, b: 1.9965, Final Loss: 0.0529
# Loss: MSE, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0015, b: 2.0002, Final Loss: 0.2816
# Loss: MSE, LR: 0.005, Steps: 3000, Noise: salt_pepper, W: 2.9982, b: 1.9942, Final Loss: 1.0331
# Loss: MSE, LR: 0.005, Steps: 3500, Noise: laplace, W: 2.9939, b: 2.0010, Final Loss: 3.8014
# Loss: MSE, LR: 0.01, Steps: 1000, Noise: gaussian, W: 2.9987, b: 2.0004, Final Loss: 0.0107
# Loss: MSE, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0013, b: 1.9995, Final Loss: 0.2451
# Loss: MSE, LR: 0.01, Steps: 3000, Noise: salt_pepper, W: 2.9982, b: 1.9957, Final Loss: 0.9742
# Loss: MSE, LR: 0.01, Steps: 3500, Noise: laplace, W: 2.9874, b: 2.0026, Final Loss: 4.1092
# Loss: MSE, LR: 0.05, Steps: 1000, Noise: gaussian, W: 3.0002, b: 1.9995, Final Loss: 0.0104
# Loss: MSE, LR: 0.05, Steps: 2500, Noise: uniform, W: 3.0036, b: 1.9954, Final Loss: 0.2632
# Loss: MSE, LR: 0.05, Steps: 3000, Noise: salt_pepper, W: 3.0070, b: 2.0029, Final Loss: 1.0264
# Loss: MSE, LR: 0.05, Steps: 3500, Noise: laplace, W: 2.9797, b: 1.9825, Final Loss: 4.1105
# Loss: MAE, LR: 0.001, Steps: 1000, Noise: gaussian, W: 1.0166, b: 0.9652, Final Loss: 1.7834
# Loss: MAE, LR: 0.001, Steps: 2500, Noise: uniform, W: 2.5154, b: 1.9285, Final Loss: 0.5495
# Loss: MAE, LR: 0.001, Steps: 3000, Noise: salt_pepper, W: 2.7090, b: 1.9979, Final Loss: 0.8388
# Loss: MAE, LR: 0.001, Steps: 3500, Noise: laplace, W: 2.6687, b: 1.9863, Final Loss: 1.6844
# Loss: MAE, LR: 0.005, Steps: 1000, Noise: gaussian, W: 2.9982, b: 2.0020, Final Loss: 0.0809
# Loss: MAE, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0000, b: 1.9935, Final Loss: 0.3912
# Loss: MAE, LR: 0.005, Steps: 3000, Noise: salt_pepper, W: 3.0003, b: 2.0042, Final Loss: 0.7806
# Loss: MAE, LR: 0.005, Steps: 3500, Noise: laplace, W: 2.9961, b: 2.0072, Final Loss: 1.6573
# Loss: MAE, LR: 0.01, Steps: 1000, Noise: gaussian, W: 3.0018, b: 2.0016, Final Loss: 0.0806
# Loss: MAE, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0093, b: 2.0036, Final Loss: 0.3847
# Loss: MAE, LR: 0.01, Steps: 3000, Noise: salt_pepper, W: 3.0059, b: 1.9855, Final Loss: 0.8271
# Loss: MAE, LR: 0.01, Steps: 3500, Noise: laplace, W: 2.9997, b: 1.9940, Final Loss: 1.4876
# Loss: MAE, LR: 0.05, Steps: 1000, Noise: gaussian, W: 2.9878, b: 1.9967, Final Loss: 0.0818
# Loss: MAE, LR: 0.05, Steps: 2500, Noise: uniform, W: 2.9739, b: 1.9878, Final Loss: 0.3775
# Loss: MAE, LR: 0.05, Steps: 3000, Noise: salt_pepper, W: 2.9942, b: 2.0101, Final Loss: 0.8119
# Loss: MAE, LR: 0.05, Steps: 3500, Noise: laplace, W: 3.0184, b: 1.9238, Final Loss: 1.7142
# Loss: Huber, LR: 0.001, Steps: 1000, Noise: gaussian, W: 1.0139, b: 0.9455, Final Loss: 1.3836
# Loss: Huber, LR: 0.001, Steps: 2500, Noise: uniform, W: 2.4361, b: 1.9163, Final Loss: 0.2477
# Loss: Huber, LR: 0.001, Steps: 3000, Noise: salt_pepper, W: 2.6605, b: 2.0015, Final Loss: 0.5078
# Loss: Huber, LR: 0.001, Steps: 3500, Noise: laplace, W: 2.6281, b: 1.9714, Final Loss: 1.2520
# Loss: Huber, LR: 0.005, Steps: 1000, Noise: gaussian, W: 2.9973, b: 1.9997, Final Loss: 0.0047
# Loss: Huber, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0000, b: 2.0062, Final Loss: 0.1318
# Loss: Huber, LR: 0.005, Steps: 3000, Noise: salt_pepper, W: 2.9957, b: 2.0059, Final Loss: 0.4328
# Loss: Huber, LR: 0.005, Steps: 3500, Noise: laplace, W: 3.0048, b: 2.0011, Final Loss: 1.1514
# Loss: Huber, LR: 0.01, Steps: 1000, Noise: gaussian, W: 3.0004, b: 1.9998, Final Loss: 0.0050
# Loss: Huber, LR: 0.005, Steps: 2500, Noise: uniform, W: 2.9980, b: 1.9965, Final Loss: 0.1262
# Loss: Huber, LR: 0.01, Steps: 3000, Noise: salt_pepper, W: 3.0015, b: 1.9952, Final Loss: 0.4304
# Loss: Huber, LR: 0.01, Steps: 3500, Noise: laplace, W: 2.9870, b: 1.9883, Final Loss: 1.1716
# Loss: Huber, LR: 0.05, Steps: 1000, Noise: gaussian, W: 2.9982, b: 1.9977, Final Loss: 0.0053
# Loss: Huber, LR: 0.05, Steps: 2500, Noise: uniform, W: 3.0011, b: 1.9861, Final Loss: 0.1348
# Loss: Huber, LR: 0.05, Steps: 3000, Noise: salt_pepper, W: 2.9936, b: 2.0339, Final Loss: 0.3875
# Loss: Huber, LR: 0.05, Steps: 3500, Noise: laplace, W: 2.9959, b: 2.0242, Final Loss: 1.1379
# Loss: Hybrid, LR: 0.001, Steps: 1000, Noise: gaussian, W: 0.9322, b: 0.8901, Final Loss: 4.0522
# Loss: Hybrid, LR: 0.001, Steps: 2500, Noise: uniform, W: 2.0868, b: 1.7536, Final Loss: 0.9872
# Loss: Hybrid, LR: 0.001, Steps: 3000, Noise: salt_pepper, W: 2.3744, b: 1.8615, Final Loss: 1.1818
# Loss: Hybrid, LR: 0.001, Steps: 3500, Noise: laplace, W: 2.5286, b: 1.9022, Final Loss: 3.0361
# Loss: Hybrid, LR: 0.005, Steps: 1000, Noise: gaussian, W: 2.9862, b: 1.9998, Final Loss: 0.0462
# Loss: Hybrid, LR: 0.005, Steps: 2500, Noise: uniform, W: 2.9974, b: 2.0059, Final Loss: 0.3341
# Loss: Hybrid, LR: 0.005, Steps: 3000, Noise: salt_pepper, W: 2.9976, b: 1.9998, Final Loss: 0.8477
# Loss: Hybrid, LR: 0.005, Steps: 3500, Noise: laplace, W: 2.9961, b: 1.9908, Final Loss: 2.6269
# Loss: Hybrid, LR: 0.01, Steps: 1000, Noise: gaussian, W: 3.0003, b: 1.9997, Final Loss: 0.0449
# Loss: Hybrid, LR: 0.005, Steps: 2500, Noise: uniform, W: 3.0042, b: 1.9963, Final Loss: 0.2885
# Loss: Hybrid, LR: 0.01, Steps: 3000, Noise: salt_pepper, W: 2.9982, b: 1.9955, Final Loss: 0.9213
# Loss: Hybrid, LR: 0.01, Steps: 3500, Noise: laplace, W: 2.9861, b: 1.9960, Final Loss: 2.8182
# Loss: Hybrid, LR: 0.05, Steps: 1000, Noise: gaussian, W: 2.9996, b: 1.9933, Final Loss: 0.0453
# Loss: Hybrid, LR: 0.05, Steps: 2500, Noise: uniform, W: 3.0166, b: 2.0039, Final Loss: 0.3192
# Loss: Hybrid, LR: 0.05, Steps: 3000, Noise: salt_pepper, W: 3.0048, b: 1.9781, Final Loss: 0.9020
# Loss: Hybrid, LR: 0.05, Steps: 3500, Noise: laplace, W: 3.0052, b: 2.0113, Final Loss: 2.8034
